# %%
import torch
torch.cuda_version
import matplotlib
# Out:
# '11.1'

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('hello\tworld')#后面3个空格
print('hellooo\tworld')
# Out:
# hello	world
# hellooo	world

# %%
print(chr(0b100111001011000))#unicode汉字编码表
# Out:
# 乘

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name = '螺蛳粉'
print('内存地址',id(name))
print('数据类型',type(name))
print('值',name)
# Out:
# 内存地址 1623268801680
# 数据类型 <class 'str'>
# 值 螺蛳粉

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = 'hello world'
print('w' in s)
print('a' in s)
# Out:
# True
# False

# %% [markdown]
# 优先级从左到右从高到低
# ![image.png](attachment:image.png)

# %%
#不使用自增变量是用_代替
for _ in range(5):
    print("好好学习")
    
print(8/2)
# Out:
# 好好学习
# 好好学习
# 好好学习
# 好好学习
# 好好学习
# 4.0

# %%
a = 0
while a<3:
    pwd=input('password:')
    if pwd=='888':
        print('密码正确')
        break
    else:
        print('密码错误')
        
    a+=1
else:
    print('3次都错')
# Out:
# password:111
# 密码错误
# password:222
# 密码错误
# password:333
# 密码错误
# 3次都错

# %%
for i in range(1,10):
    for j in range(1,i+1):
        print(i,'*',j,'=',i*j,end='  ')
    print()
# Out:
#   File "<ipython-input-7-e5144ca7ada1>", line 3
#     print(i,'*',j,'=',i*j,end='  ')
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# 列表，字典，元组，集合

# %%
lst = ['hello','123',99,'hello']

print(lst.index('hello',1,4))
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-2b4add40d874> in <module>
#       2
#       3 print(lst.index('hello',1,4))
# ----> 4 print(lst[1,3])
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lst = [10,2,30,40,50,60,70,80]
print(lst[1:6:1])
lst2 = lst[1:6]
print(lst2)
#负数情况
print(lst[::-1])
#查询
print(10 in lst)
print(100 not in lst)
# Out:
# [2, 30, 40, 50, 60]
# [2, 30, 40, 50, 60]
# [80, 70, 60, 50, 40, 30, 2, 10]
# True
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lst = [10,20,30]
print(lst)
#lst.append(100)
#print(lst)
lst2 = [1,2]
# lst.extend(lst2)
# print(lst)
#切片
lst[3:]=lst2
print(lst)
lst[1:3]=[]#删除多个元素：即用空列表代替
print(lst)
# Out:
# [10, 20, 30]
# [10, 20, 30, 1, 2]
# [10, 1, 2]

# %%
lst = [10,30,20,40,50]
print(lst)
lst.sort()#默认升序;此外还有内置函数sorted
print(lst)
lst.sort(reverse = True)
print(lst)
# Out:
# [10, 30, 20, 40, 50]
# [10, 20, 30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
lst = [i for i in range(1,10)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-62b1693783f0> in <module>
#       2 lst1 = [0]
#       3 for i in range(1,10):
# ----> 4     lst1[i] = i
#       5     i += 1
#       6
#
# IndexError: list assignment index out of range

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scores={'张三':100,'李四':98,'王五':45}
print(scores)
student = dict(name='aaa',age=111)
print(student)
print(type(scores))
print(scores['张三'])
print(scores.get('张三'))
print(scores.get('张'))
print(scores.get('李',99))
print(scores)
scores['赵六'] = 10
print(scores)
# Out:
# {'张三': 100, '李四': 98, '王五': 45}
# {'name': 'aaa', 'age': 111}
# <class 'dict'>
# 100
# 100
# None
# 99
# {'张三': 100, '李四': 98, '王五': 45}
# {'张三': 100, '李四': 98, '王五': 45, '赵六': 10}

# %%
scores={'张三':100,'李四':98,'王五':45}

#键
keys = scores.keys()
print(keys)
print(type(keys))
print(list(keys))

#获取所有的value
values=scores.values()
print(values)
print(type(values))
print(list(values))

#获取所有的key-value对
items=scores.items()
print(items)
print(list(items))#元组()

for item in scores:
    print(item,scores[item],scores.get(item))
# Out:
# dict_keys(['张三', '李四', '王五'])
# <class 'dict_keys'>
# ['张三', '李四', '王五']
# dict_values([100, 98, 45])
# <class 'dict_values'>
# [100, 98, 45]
# dict_items([('张三', 100), ('李四', 98), ('王五', 45)])
# [('张三', 100), ('李四', 98), ('王五', 45)]
# 张三 100 100
# 李四 98 98
# 王五 45 45

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
items = {'aaa','bbb','ccc'}
scores = [1,2,3]
d = {item:scores for item,score in zip(items,scores)}
print(d)
# d = {item.upper():scores for item,score in zip(items,scores)}
# .title()每个单词首字母都大写
# .capitalize()首字母大写
# .lower()改小写
# print(d)
# scores2 = [1,2,3,4,5,6]
d2 = {item:scores for item,score in zip(items,scores2)}
print(d2)
# Out:
# {'bbb': [1, 2, 3], 'ccc': [1, 2, 3], 'aaa': [1, 2, 3]}
# {'BBB': [1, 2, 3], 'CCC': [1, 2, 3], 'AAA': [1, 2, 3]}
# {'bbb': [1, 2, 3], 'ccc': [1, 2, 3], 'aaa': [1, 2, 3]}

# %%
# ’不可变序列，可变序列’'
# ’可变序列列表，字典’’’
lst = [10,20,30]
print(id(lst))
lst.append(40)
print(id(lst))
#不可变序列，字符串,元组’,
s='hello'
print(id(s))
s=s+'world'
print(id(s))
print(s)
# Out:
# 1623269841408
# 1623269841408
# 1623269898928
# 1623269899504
# helloworld

# %% [markdown]
# ![image.png](attachment:image.png)
# 对于第三点不加逗号则会变成字符串类型

# %%
t1 = ('python','hello',90)
t2 = tuple(('python','hello',90))
print(t1)
print(t2)
# Out:
# ('python', 'hello', 90)
# ('python', 'hello', 90)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
set2 = {'1','2','python',3,4}
print(set2)
# Out:
# {3, 4, '2', '1', 'python'}

# %%
help (set)
# Out:
# Help on set object:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = 'hello,python'

print(s.center(20,'*'))
print(s.ljust(20,'*'))
print(s.ljust(20))
# Out:
# ****hello,python****
# hello,python********
# hello,python

# %%
s = 'hello world python'
lst = s.split()#split默认从左边分割，rsplit从右边开始分割
print(lst)
s1 = 'hello|world|python'
print(s1.split(sep='|'))
print(s1.split(sep='|',maxsplit=1))
# Out:
# ['hello', 'world', 'python']
# ['hello', 'world', 'python']
# ['hello', 'world|python']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = 'hello,python'
s1 = s[:5]
s2 = s[6:]
print(s1)
print(s2)
s3 = '!'
newstr = s1+s3+s2
print(newstr)
##切片[start:end:step]左右都是开区间
print(s[1:5:1])
print(s[::-1])
print(s[-6::1])#从索引为-6开始一直到最后
# Out:
# hello
# python
# hello!python
# ello
# nohtyp,olleh
# python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = '张三'
age = 20
print('我叫%s，今年%d岁'%(name,age))
print('我叫{},今年{}'.format(name,age))
print('我叫{0},今年{1}'.format(name,age))
print(f'我叫{name}，今年{age}岁')
print('{0}'.format(3.1415926))
print('{0:.3}'.format(3.1415926))
print('{0:.3f}'.format(3.1415926))#0可以不写
# Out:
# 我叫张三，今年20岁
# 我叫张三,今年20
# 我叫张三,今年20
# 我叫张三，今年20岁
# 3.1415926
# 3.14
# 3.142

# %%
print('%10d'%99)
print('%.6f'%3.1415926)
print('%.6f'%3.141)
print('hellohello')
# Out:
#         99
# 3.141593
# 3.141000
# hellohello

# %%
s = '天涯共此时'
print(s.encode(encoding = 'GBK'))
print(s.encode(encoding='UTF-8'))
# Out:
# b'\xcc\xec\xd1\xc4\xb9\xb2\xb4\xcb\xca\xb1'
# b'\xe5\xa4\xa9\xe6\xb6\xaf\xe5\x85\xb1\xe6\xad\xa4\xe6\x97\xb6'

# %%
byte = s.encode(encoding='GBK')
print(byte.decode(encoding='GBK'))
# Out:
# 天涯共此时
